# %% [markdown]
# ### Part 2: The Stability Experiment

# %% [markdown]
# ##### *Import Libraries*

# %%
import pandas as pd
from utils.prompts import render
from utils.llm_client import LLMClient
from utils.router import pick_model
from utils.logging_utils import log_llm_call

# %% [markdown]
# ##### *Load data  from scenarios.txt*

# %%
input_scenarios_path = '../data/scenarios.txt'

try:
    with open(input_scenarios_path, 'r') as f:
        content = f.read()
        scenarios = [s.strip() for s in content.split('\n\n') if s.strip()]
    print(f"{len(scenarios)} scenarios loaded")
except FileNotFoundError:
    print("File not found")
    scenarios = []
# Out:
# 2 scenarios loaded

# %% [markdown]
# ##### *Setup LLM Client*

# %%
model = pick_model('openai', 'general')
client = LLMClient('openai', model)

# %% [markdown]
# ##### *Temperature Stress Test*

# %%
for i, scenario in enumerate(scenarios):
    print(f"Testing {scenario.splitlines()[0]}") 
    
    # CoT prompt
    prompt_text, spec = render(
                                'cot_reasoning.v1',
                                role='Crisis Commander',
                                problem=scenario,
                                context='You must decide who to save first. Explain your reasoning step-by-step.'
                                )
    
    # Safe Mode (Temperature = 0.0)
    print("\n-Safe Mode-")
    response_safe = client.chat([{'role': 'user', 'content': prompt_text}], temperature=0.0)
    print(f"{response_safe['text'].strip()}\n")
    log_llm_call('openai', model, 'stability_safe', response_safe['latency_ms'], response_safe['usage'])
    
    print(f"{'-'*100}")

    # Chaos Mode (Temperature = 1.0)
    print("\n-Chaos Mode-")
    for run in range(1, 4):
        response_chaos = client.chat([{'role': 'user', 'content': prompt_text}], temperature=1.0)
        print(f"\n[Run {run}]:\n{response_chaos['text'].strip()}")
        log_llm_call('openai', model, 'stability_chaos', response_chaos['latency_ms'], response_chaos['usage'])
# Out:
# Testing SCENARIO A: THE KANDY LANDSLIDE
#
# -Safe Mode-
# **Reasoning Steps:**
#
# 1. **Assess Immediate Life Threat:** The uncle is in a critical situation, climbing a tree as water rises. This requires immediate action to rescue him.
#
# 2. **Assess Immediate Health Threat:** The diabetic patient who has collapsed needs insulin urgently. This is also a life-threatening situation that must be addressed quickly.
#
# 3. **Evaluate Resources:** Determine if there are any available resources in the factory that can be used for both rescue and medical assistance.
#
# 4. **Prioritize Actions:** Given the immediate life threat of the uncle and the health threat of the diabetic patient, prioritize actions based on the severity of the threats.
#
# 5. **Plan for Hunger:** While addressing the immediate threats, consider how to manage the hunger of the 40 people, but this is a lower priority compared to the life and health threats.
#
# 6. **Coordinate Rescue Efforts:** If possible, organize a team to assist in the rescue of the uncle while simultaneously preparing to provide insulin to the diabetic patient.
#
# **Answer:**
# 1. Immediately send a team to rescue the uncle from the tree.
# 2. Locate and administer insulin to the diabetic patient.
# 3. After addressing the immediate threats, organize food distribution for the 40 hungry people.
#
# ----------------------------------------------------------------------------------------------------
#
# -Chaos Mode-
#
# [Run 1]:
# **Reasoning Steps:**
#
# 1. **Assess immediate threats**: Identify the two critical situations: the uncle in the line rooms (life threat) and the diabetic patient needing insulin (health threat).
#
# 2. **Prioritize rescue efforts**: Determine which threat poses the highest risk to life based on immediacy and potential for fatality.
#
# 3. **Consider resources available**: Evaluate what resources are available on-site for both rescue and medical needs.
#
# 4. **Plan for maintaining health**: Address the immediate health threat of the diabetic patient to stabilize their condition.
#
# 5. **Consider the food shortage**: While important, the hunger of the 40 people is less immediate than the life and health threats.
#
# 6. **Formulate rescue strategy**: Develop a plan that prioritizes safety for both the rescuer and the individuals in immediate danger.
#
# **Answer:**
# 1. Send a person to rescue the uncle from the tree as a priority due to the immediate life threat.
# 2. Simultaneously, locate and administer insulin to the diabetic patient to stabilize their health condition.
# 3. After addressing these urgent threats, assess options for food distribution to the 40 people in a safe manner.
#
# [Run 2]:
# ### Reasoning Steps:
# 1. **Assess Immediate Life Threat**: The uncle stuck in the line rooms is at immediate risk due to rising water. Rescue is the top priority.
# 2. **Evaluate Immediate Health Threat**: The diabetic patient who is collapsed needs urgent medical attention and insulin, requiring next priority.
# 3. **Identify Resource Needs**: With 40 hungry people, addressing their needs will be important soon but is less urgent than the life and health threats.
# 4. **Plan for Rescue and Aid**:
#    - Coordinate a rescue operation for the uncle while ensuring someone is prepared to provide medical assistance for the diabetic patient.
#    - Address the food needs once rescue and health emergencies are mitigated.
# 5. **Allocate Resources**: Identify any available tools, personnel, or materials that can aid in both the rescue of the uncle and the medical assistance for the diabetic patient.
#
# ### Answer:
# 1. Prioritize the rescue of the uncle trapped from rising water.
# 2. While the rescue is in progress, arrange for immediate insulin and care for the diabetic patient.
# 3. After addressing immediate threats, organize food distribution for the 40 hungry people.
#
# [Run 3]:
# **Reasoning Steps:**
#
# 1. **Assess Immediate Life Threat**: Prioritize the rescue of the uncle climbing the tree as it's an immediate life-threatening situation due to rising water.
#
# 2. **Address Immediate Health Threat**: Next, the diabetic patient requires insulin urgently to stabilize their health condition.
#
# 3. **Evaluate Resource Allocation**: With 40 people needing food, assess available resources for meal distribution while ensuring safety and accessibility.
#
# 4. **Coordinate a Rescue Plan**: Organize a team to reach the uncle using ropes or other means while ensuring the diabetic patient receives insulin as soon as possible.
#
# 5. **Set Up Food Distribution**: After addressing immediate threats, gather food and plan efficient distribution to ensure all individuals can eat.
#
# 6. **Continuous Monitoring**: Keep monitoring the situations of both the uncle and the diabetic patient, adjusting plans as circumstances change.
#
# **Answer:**
# 1. Initiate a rescue operation for the uncle stuck in the line rooms.
# 2. Secure the insulin for the diabetic patient as soon as possible.
# 3. Prepare and distribute food to the 40 hungry individuals.
# Testing SCENARIO B: THE GAMPAHA HOSPITAL
#
# -Safe Mode-
# **Reasoning Steps:**
#
# 1. **Assess Immediate Needs**: The ICU has three patients on ventilators with only 2 hours of battery backup, making this the highest priority due to the critical nature of their condition.
#
# 2. **Evaluate Flood Risk**: The ground floor ward with 50 bedridden elderly patients is at high risk due to flooding, but they are not in immediate danger of losing life support.
#
# 3. **Plan for Generator Use**: Since the generator truck will arrive in 30 minutes and can only power one section, the ICU must be prioritized to ensure ventilators remain operational.
#
# 4. **Implement Flood Mitigation**: While waiting for the generator, initiate flood mitigation measures for the ground floor ward, such as moving patients to higher ground if possible or using sandbags to divert water.
#
# 5. **Communicate with Staff**: Ensure all staff are aware of the plan and are prepared to act quickly once the generator arrives.
#
# 6. **Prepare for Transition**: Once the generator arrives, connect it to the ICU to restore power immediately, then assess the situation in the ground floor ward for further action.
#
# **Answer:** Prioritize powering the ICU with the generator upon arrival to support the ventilators. Implement flood mitigation for the ground floor ward while awaiting the generator.
#
# ----------------------------------------------------------------------------------------------------
#
# -Chaos Mode-
#
# [Run 1]:
# **Reasoning Steps:**
#
# 1. **Assess Patient Needs**: Identify critical requirements of the three ventilator patients in the ICU as they are on battery backup for only two hours.
#
# 2. **Evaluate Flood Risk**: The flood water entering the ground floor poses a high risk to the 50 bedridden elderly patients who may require immediate evacuation.
#
# 3. **Weigh Power Needs**: With the generator arriving in 30 minutes but capable of powering only one section, prioritize which section (ICU or ground floor) needs power more urgently based on immediate risks.
#
# 4. **Make a Decision**: Given the critical status of the ICU patients, they should be prioritized for immediate power restoration with the generator.
#
# 5. **Implement Evacuation Plan**: While waiting for the generator, prepare for an organized evacuation of the 50 bedridden elderly patients from the ground floor to a safer area to avoid flooding.
#
# 6. **Communicate and Coordinate**: Ensure all staff are informed of the plan, assignments are clear, and coordination with emergency services for potential evacuation assistance is established.
#
# **Answer:**
# Power the ICU with the generator when it arrives, and simultaneously evacuate the 50 elderly patients from the ground floor to a safer location away from the flooding.
#
# [Run 2]:
# 1. **Assess Patient Needs**: The three patients on ventilators in the ICU are critical and require immediate continuous power.
#
# 2. **Evaluate Flood Risk**: The 50 elderly bedridden patients on the ground floor are at high risk due to flooding, which may require evacuation or immediate action.
#
# 3. **Identify Resource**: A generator truck is arriving in 30 minutes, which can only power one section of the hospital.
#
# 4. **Prioritize**: Prioritize the ICU to ensure the ventilated patients remain stable, as they are more critical than moving flooded patients.
#
# 5. **Plan for Flooding**: As soon as the generator arrives, a plan must be in place to either evacuate the elderly patients or provide an alternative shelter.
#
# 6. **Coordinate Actions**: Inform staff to prepare for moving the elderly patients to an upper floor or a safer location as soon as flood waters rise.
#
# **Answer**: Power the ICU immediately with the arriving generator to support ventilated patients. Prepare to evacuate or relocate the 50 elderly patients on the ground floor as a secondary priority.
#
# [Run 3]:
# **Reasoning Steps:**
#
# 1. **Identify Immediate Critical Needs:** Assess the ICU situation with three patients on ventilators needing power urgently to prevent respiratory failure.
#
# 2. **Evaluate Flood Impact:** Understand the risk to the 50 bedridden elderly patients on the ground floor. Floodwaters pose a significant health risk but are less immediate than the ICU needs.
#
# 3. **Consider Available Resources:** A generator truck is arriving in 30 minutes, but it can only power one section.
#
# 4. **Prioritize Based on Severity:** Given that the ICU patients are critically dependent on ventilators and face imminent danger if power is not restored, they must be prioritized over the flood risk in the ward.
#
# 5. **Plan for Flood Mitigation:** While waiting for the generator, consider alternative actions to mitigate flooding risk (such as moving elderly patients to higher ground or using sandbags if available).
#
# 6. **Communicate with Staff:** Ensure ICU staff and flood ward staff are informed of the plan and prepared for potential patient relocation.
#
# 7. **Set Up for Arrival of Generator:** Prepare to connect the generator to the ICU immediately upon arrival.
#
# **Answer:** Prioritize powering the ICU with the arriving generator to support the three ventilator patients. Meanwhile, assess and implement immediate flood mitigation strategies for the 50 elderly patients on the ground floor.

# %% [markdown]
# #### How the Chaos output drifted or hallucinated compared to the Safe output?
#
# ##### Scenario A: The Kandy Landslide
# The Safe output correctly treats the uncle’s rescue and the diabetic patient’s insulin as urgent, then addresses hunger. The Chaos outputs start to guess. Some of them suggest the diabetic patient might be able to wait or assume insulin or food could already be available. These details are not mentioned in the scenario, so they are assumptions, not facts.
#
# ##### Scenario B: The Gampaha Hospital
# The Safe output makes a clear choice by using the generator for the ICU because the ventilator patients are in immediate danger, and move the elderly patients away from flooding. The Chaos outputs keep the same decision but add ideas like manual ventilation or extra batteries. These were never stated in the scenario and make the reasoning less clean.
#
#
# ##### *The Safe outputs stayed grounded in the exact information provided and the Chaos outputs kept the same final decision but add guesses and unnecessary details were not given.*
